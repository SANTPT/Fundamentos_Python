# %% [markdown]
# # Ejemplo de Indentación de Código y comentario

# %%
try:
    edad = int(input("¿Cuántos años tienes? "))
    
    if edad >= 0:
        if edad >= 18:
            print("Ya puedes conducir.")
        else:
            print("Aún te faltan unos años para conducir.")
    else:
        print("La edad no puede ser negativa.")

except ValueError:
    print("Error: Por favor, introduce un número válido.")
# Out:
# Aún te faltan unos años para conducir.

# %% [markdown]
# ### Documentación tipo Docstring

# %%
'''
Este código es un ejemplo de 
Documentacion tipo Docstring
'''

# %% [markdown]
# Ejemplo de documentacion comentario

# %%
# Ejemplo de  comentario

# %% [markdown]
# ### Snake case y Sensibilidad a Mayúsculas

# %%
# Snake case
nombre_usuario = "Juan"
edad_usuario = 25
Edad_usuario = 35

def verificar_mayoria_edad(edad):
    if edad >= 18:
        print(f"{nombre_usuario} es mayor de edad.")

verificar_mayoria_edad(edad_usuario)

# Sensible a mayúsculas y minúsculas
print(nombre_usuario)
print(Edad_usuario)
# Out:
# Juan es mayor de edad.
# Juan
# 35

# %% [markdown]
# ### Declaración de Variables y Tipos de Datos

# %%
# Texto (String) - Usa comillas dobles o simples
nombre_usuario = "Alex"

# Números enteros (Integer)
edad = 28

# Números con decimales (Float)
precio_producto = 19.99

# Valores lógicos (Boolean) - Siempre con Mayúscula inicial
es_estudiante = True
tiene_descuento = False

# Asignar diferentes valores a diferentes variables
x, y, z = 10, 20, 30

# Asignar el mismo valor a varias variables
inicio = fin = contador = 0

# Declaramos una variable que existe, pero no tiene valor aún
resultado_examen = None

print (nombre_usuario)
print(edad)
print (precio_producto)
print(es_estudiante )
print(tiene_descuento)
print(resultado_examen)
# Out:
# Alex
# 28
# 19.99
# True
# False
# None

# %% [markdown]
# ### Formateo de Cadenas: f-strings

# %%
nombre = "Elena"
puntos = 95

# Directo, limpio y permite operaciones dentro de las llaves
mensaje = f"Hola {nombre}, tu puntuación es de {puntos} puntos."
print(mensaje)

# Ejemplo con operación:
print(f"El doble de tus puntos es {puntos * 2}")
# Out:
# Hola Elena, tu puntuación es de 95 puntos.
# El doble de tus puntos es 190

# %% [markdown]
# ### Formateo de Cadenas: Método .format()

# %%
nombre = "Elena"
puntos = 95

# Se usan llaves vacías como "espacios reservados"
mensaje = "Hola {}, tu puntuación es de {} puntos.".format(nombre, puntos)
print(mensaje)

# También puedes usar índices para repetir valores
repetido = "Usuario: {0}, ¿verdad {0}?".format(nombre)
print(repetido)
# Out:
# Hola Elena, tu puntuación es de 95 puntos.
# Usuario: Elena, ¿verdad Elena?

# %% [markdown]
# ### Formateo de Cadenas: Operador %

# %%
nombre = "Elena"
puntos = 95

# %s para texto (string), %d para números enteros (decimal/integer)
mensaje = "Hola %s, tu puntuación es de %d puntos." % (nombre, puntos)
print(mensaje)
# Out:
# Hola Elena, tu puntuación es de 95 puntos.

# %% [markdown]
# ### Conversión Explícita (Casting)

# %%
# De string a int
puntuacion_texto = "100"
puntuacion_int = int(puntuacion_texto)
puntuacion_total = puntuacion_int + 5
print(f"Puntuación total: {puntuacion_total}")

# De int a string
edad = 25
mensaje = "Mi edad es " + str(edad)
print(mensaje)

# De float a int
precio = 19.99
precio_entero = int(precio)
print(f"Original: {precio}, Convertido a int: {precio_entero}")

# De int a float
puntuacion_base = 100
puntuacion_decimal = float(puntuacion_base)
print(f"Puntuación base: {puntuacion_base}, Convertido a float: {puntuacion_decimal}")

# De string a float
precio_texto = "25.50"
precio_float = float(precio_texto)
print(f"Precio float: {precio_float}")
# Out:
# Puntuación total: 105
# Mi edad es 25
# Original: 19.99, Convertido a int: 19
# Puntuación base: 100, Convertido a float: 100.0
# Precio float: 25.5

# %% [markdown]
# ### Conversión Implícita

# %%
numero_entero = 10
numero_decimal = 5.5

# Python convierte automáticamente el entero a decimal para sumar
resultado = numero_entero + numero_decimal

print(f"Resultado implícito: {resultado}, tipo: {type(resultado)}")
# Out:
# Resultado implícito: 15.5, tipo: <class 'float'>

# %% [markdown]
# ### Conversión a Booleano (bool)

# %%
print(f"bool(0): {bool(0)}")      # False
print(f"bool(42): {bool(42)}")     # True
print(f"bool(''): {bool('')}")     # False
print(f"bool('Hola'): {bool('Hola')}") # True
# Out:
# bool(0): False
# bool(42): True
# bool(''): False
# bool('Hola'): True
